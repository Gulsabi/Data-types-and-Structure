# %% [markdown]
# 1. What are data structure, and why are they important?
#    -  Data Structure >> a way of organising and storing data so that it can be
#       accessed and manipulated efficiently.Data structure are important because they help computers process large, complex sets of informationefficiently and make code easier to understand.

# %% [markdown]
# 2. Explain the difference between mutable and immutable data types with example.
#     - The main difference between mutable and immutable data types is that mutable data type can be changed after creation, while immutable data type cannot changed.
#      Examples of mutable data type are list, dictionaries, and sets in python.
#      Examples of immutable data type are string and tuple.

# %% [markdown]
# 3. What are the main difference between list and tuple in python?
#    - list are mutable, meaning they can be changed, while tuples are immutable, meaning they cannot be changed.
#    Tuples can be used as keys in dictionaries, while list cannot. Tuples can be used as element in sets, while list cannot.

# %% [markdown]
# 4. Describe how dictionaries store data.
#    - Dictionaries are used to store data values in key:value pairs. A dictionary is a collection which is ordered, changeable and do not allow duplicates.

# %% [markdown]
# 5. why might you use a set instead of a list in python?
#    - One of the main advantage of using sets in python is that they are highly optimized for membership tests. For example, sets do membership tests a lot more efficiently than list.

# %% [markdown]
# 6. What is a string in python, and how is it different from a list?
#    - A string is a sequence of characters between single or double quotes. A list is a sequence of items, where each item could be of any data type like an integer, float, string, boolean value, complex value.

# %% [markdown]
# 7. How do tuples ensure data integrity in python?
#    - Tuples are immutable to ensure that their contents remain constant throughout their lifecycle, guarenteening data integrity and reliability. This immutability allows tuples to be used as keys in dictionaries and elements in sets.

# %% [markdown]
# 8. What is a hash table, and how does it relate to dictionaries in python?
#    - In python, a hash table is a data structure that's used to implement dictionaries. Python dictionaries are built using hash tables and the open addressing collision resolution method. The key in a python dictionary are hashable.

# %% [markdown]
# 9. Can list contain different data types in python?
#    - List can contain items of different types at the same time(including string, integer, float, boolean value and complex value). List are mutable and dynamic,list items can be added, removed or changed after the list is defined.

# %% [markdown]
# 10. Explain why strings are immutable in python.
#     - In python, string are made immutable so that programmers cannot alter the contents of the object(even by mistake). This avoids unnecessary bugs. Some other immutable object are integer, float, tuple, and bool.

# %% [markdown]
# 11. What advantage do dictionaries offer over list for certain tasks?
#     - Dictionaries are unordered collection of unique elements, while list are
#       ordered collection of data.
#       Dictionaries are faster than list for lookups and searches, especially for large list.
#       Dictionaries cannot contain duplicates keys, while list can.

# %% [markdown]
# 12. Describe a scenario where using a tuple would be preferable over a list.
#     - Tuples are more lightweight than list and might be quicker to generate, access, and iterate through since they are immutable. Using a tuple can be more effective than using a list if you have a huge collection of data that you need to storeand use regularly and that data does not need to be altered.

# %% [markdown]
# 13. How do sets handle duplicates value in python?
#     - Items of a set in python are immutable(unchangeable), do not duplicate values, and unordered. Thus, items in a set do not appear in a stipulated manner,  means they can appear in a different order every time it is used. Due to this , sets items cannot be referred to by key or index.

# %% [markdown]
# 14. How does the "in" keyword work differently for list and dictionaries?
#     - To check if a variable exicts in a list in python,use the "in" keyword. For example, if variable in my_list:evaluates to trur if variable is in my_list.

# %% [markdown]
# 15. Can you modifiythe element of a tuple? Explain why or why not?
#     - No, you cannot modify the elements of a tuple in python because tuples are "immutable," meaning once created, their elements cannot be changed, added, or removed; attempting to do so will result in a TypeError,

# %% [markdown]
# 16. What is a nested dictionary, and give an example of its use case?
#     - Anested dictionary is a collection of a dictionaries inside a single dictionary, and is a useful way to represent data with multiple layers of organization.
#      Some use case are:
#      Track product categories, subcategories, and individual product details.

# %% [markdown]
# 17. Describe the time complexity of accessing elements in a dictionary.
#     - The time complexity of accessing an element in a python dictionary is O(1), which means it takes a constant amount of time regardless of the dictionary's size. The space complexity is also O(1) because no additional memory is used to access the element.

# %% [markdown]
# 18. In what situations are list preferred over dictionaries?
#     - A list can store any data type. In contrast, key in the dictionary can be of any immutable data type, and values can be of any data type. List perform faster for ordered operations like sorting, while dictionaries perform faster for Lookup operation.

# %% [markdown]
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#     - Python dictionaries are an unordered collection of item, while other compound data types have only value as an element,a dictionary has a key:value pair. Dictionaries are optimized to retrieve values when the key is known.

# %% [markdown]
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
#     - A list is an ordered collection of items, whereas a dictionary is an unordered data collection in a key:value pair.
#      Elements from the list can be accessed using the index, while the elements of the dictionary can be accessed using keys.

# %% [markdown]
# #  **Practical** **Questions**

# %% [markdown]
# 1. Write a code to create a string with your name and print it.

# %%
name = "Sabi"
name
# Out:
# 'Sabi'

# %%
print("My name is", name)
# Out:
# My name is Sabi

# %% [markdown]
# 2. Write a code to find the length of the string "Hello world".

# %%
a = "Hello world"
a
# Out:
# 'Hello world'

# %%
print(len(a))
# Out:
# 11

# %% [markdown]
# 3. Write a code to slice the first 3 characters from the string "Python Programming"

# %%
string = "Python Programming"
string[0:4]
# Out:
# 'Pyth'

# %% [markdown]
# 4. Write a code to convert the string "hello" to uppercase.

# %%
string = "hello"
string.upper()
# Out:
# 'HELLO'

# %% [markdown]
# 5. Write a code to replace the word "apple"with "orange" in the string "I like apple".

# %%
string = "I like apple"
string.replace("apple","orange")
# Out:
# 'I like orange'

# %% [markdown]
# 6. Write a code to create a list with number 1 to 5 and print it.

# %%
num = range(1 , 5)
print(list(num))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].

# %%
list = [1, 2, 3, 4]
list
# Out:
# [1, 2, 3, 4]

# %%
list.append(10)
list
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]

# %%
list = [1, 2, 3, 4, 5]
list
# Out:
# [1, 2, 3, 4, 5]

# %%
list.remove(3)
list
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

# %%
list = ['a', 'b', 'c', 'd']
list
# Out:
# ['a', 'b', 'c', 'd']

# %%
list[1]
# Out:
# 'b'

# %%
list[2]
# Out:
# 'c'

# %% [markdown]
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
list = [10, 20, 30, 40, 50]
list
# Out:
# [10, 20, 30, 40, 50]

# %%
list.reverse()
list
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# 11. Write a code to create a tuple with the element 10, 20, 30 and print it.

# %%
b = (10, 20, 30)
type(b)
# Out:
# tuple

# %%
print(b)
# Out:
# (10, 20, 30)

# %% [markdown]
# 12. Write a code to access the first element of the tuple('apple', 'banana', 'cherry').

# %%
tuple = ('apple', 'banana', 'cherry')
print(tuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
tuple[0]
# Out:
# 'apple'

# %%
tuple[1]
# Out:
# 'banana'

# %% [markdown]
# 13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)

# %%
tuple = (1, 2, 3, 2, 4, 2)
tuple.count(2)
# Out:
# 3

# %% [markdown]
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
tuple = ('dog', 'cat', 'rabbit')
tuple.index('cat')
# Out:
# 1

# %% [markdown]
# 15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

# %%
tuple = ('apple', 'orange', 'banana')
if 'banana' in tuple:
  print('tuple contain banana')
# Out:
# tuple contain banana

# %% [markdown]
# 16. Write a code to create a set with the element 1, 2, 3, 4, 5 and print it.

# %%
s = {1, 2, 3, 4, 5}
type(s)
# Out:
# set

# %%
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 17. Write a code to add the element 6 to the set {1, 2, 3, 4}

# %%
s = {1, 2, 3, 4}
s.add(6)
s
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# 18. Write a code to create a tuple with the elements 10, 20, 30 and print it.

# %%
b = (10, 20, 30)
type(b)
# Out:
# tuple

# %%
print(b)
# Out:
# (10, 20, 30)

# %% [markdown]
# 19. Write a code to access  the first element of the tuple ('apple', 'banana', 'cherry').

# %%
tuple = ('apple', 'banana', 'cherry')
print(tuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
tuple[1]
# Out:
# 'banana'

# %%
tuple[0]
# Out:
# 'apple'

# %% [markdown]
# 20. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)

# %%
tuple = (1, 2, 3, 2, 4, 2)
tuple.count(2)
# Out:
# 3

# %% [markdown]
# 21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
tuple = ('dog', 'cat', 'rabbit')
tuple.index('cat')
# Out:
# 1

# %% [markdown]
# 22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

# %%
tuple = ('apple', 'orange', 'banana')
if 'banana' in tuple:
  print('tuple contain banana')
# Out:
# tuple contain banana

# %% [markdown]
# 23. Write a code to create a set with the element 1, 2, 3, 4, 5 and print it.

# %%
s = {1, 2, 3, 4, 5}
type(s)
# Out:
# set

# %%
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 24. Write a code to add the element 6 to the set {1, 2, 3, 4}

# %%
s = {1, 2, 3, 4}
s.add(6)
s
# Out:
# {1, 2, 3, 4, 6}
